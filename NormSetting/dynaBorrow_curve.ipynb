# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle
from pathlib import Path
import pandas as pd
import seaborn as sns
from easydict import EasyDict as edict
from tqdm import tqdm_notebook as tqdm
from collections import defaultdict as ddict
from pprint import pprint

# %matplotlib inline

# %%
def load_pkl(f):
    with open(f, "rb") as fi:
        data = pickle.load(fi)
    return data

# %%
def getPlotData(data):
    means = []
    UpQs = []
    LowQs = []
    theta0s = []
    for key, item in data.items():
        theta0s.append(float(key)) 
        means.append(np.mean(item))
        UpQs.append(np.quantile(item, 0.975))
        LowQs.append(np.quantile(item, 0.025))
    sortIdxs = np.argsort(theta0s)
    theta0s = np.array(theta0s)[sortIdxs]
    means = np.array(means)[sortIdxs]
    UpQs = np.array(UpQs)[sortIdxs]
    LowQs = np.array(LowQs)[sortIdxs]
    return edict({"means": means, "theta0s":theta0s, 
             "UpQs": UpQs, "LowQs":LowQs})

# %% [markdown]
# # 1. obtain the data

# %%
root = Path("./")

# %%
n = 80
if n == 40:
    fname = ""
else:
    fname = "_80"

# %% [markdown]
# ## 1.1 UIPD-M

# %%
rawUIPDM = load_pkl(root/f"Boxplot_M_UIPD100{fname}.pkl")

# %%
UIPDM = ddict(list)
for dat in rawUIPDM:
    for key, item in dat.items():
        UIPDM[key].append(np.mean(item))

# %%
plotData = getPlotData(UIPDM)
plt.plot(plotData.theta0s, plotData.means, "o-", color="#F25757")
plt.fill_between(plotData.theta0s, plotData.LowQs, plotData.UpQs, 
                 alpha=0.2, facecolor="#F25757")

# %% [markdown]
# ### UIPD-M-Long

# %%
rawUIPDM_ext = load_pkl(root/f"Boxplot_M_UIPD100{fname}_dev.pkl")
UIPDM_ext = ddict(list)
for dat in rawUIPDM_ext:
    for key, item in dat.items():
        UIPDM_ext[key].append(np.mean(item))

# %%
plotData_ext = getPlotData(UIPDM_ext)
allMeans = np.concatenate([plotData.means, plotData_ext.means])
allTheta0s = np.concatenate([plotData.theta0s, plotData_ext.theta0s])

plt.figure(figsize=[5, 5])
plt.plot(allTheta0s, allMeans, "o-", color="#F25757")

plt.xlabel(r"$\theta_0$")
plt.ylabel(r"Posterior mean of $M$")
# plt.savefig("../plots/dynaNormUIPD_Long.pdf")
# Out:
# Text(0, 0.5, 'Posterior mean of $M$')

# %% [markdown]
# ## 1.2 UIPD-w

# %%
rawUIPDw = load_pkl(root/f"Boxplot_w_UIPD100{fname}.pkl")

# %%
UIPDm1 = ddict(list)
UIPDm2 = ddict(list)
UIPDw1 = ddict(list)
UIPDw2 = ddict(list)
for dat in rawUIPDw:
    for key in dat[0].keys():
        ws = dat[0][key]
        Ms = dat[1][key]
        ms = ws * Ms.reshape(-1, 1)
        w = ws.mean(axis=0)
        m = ms.mean(axis=0)
        UIPDw1[key].append(w[0])
        UIPDw2[key].append(w[1])
        UIPDm1[key].append(m[0])
        UIPDm2[key].append(m[1])

# %%
plotDatam1 = getPlotData(UIPDm1)
plotDatam2 = getPlotData(UIPDm2)
plotDataw1 = getPlotData(UIPDw1)
plotDataw2 = getPlotData(UIPDw2)

plt.figure(figsize=[10, 5])
plt.subplot(121)
plt.plot(plotDatam1.theta0s, plotDatam1.means, "*-", color="#F25757")
plt.fill_between(plotDatam1.theta0s, plotDatam1.LowQs, plotDatam1.UpQs, 
                 alpha=0.2, facecolor="#F25757")
plt.plot(plotDatam2.theta0s, plotDatam2.means, "o-.", color="#1094E9")
plt.fill_between(plotDatam2.theta0s, plotDatam2.LowQs, plotDatam2.UpQs, 
                 alpha=0.2, facecolor="#1094E9")

plt.subplot(122)
plt.plot(plotDataw1.theta0s, plotDataw1.means, "-*", color="#F25757")
plt.fill_between(plotDataw1.theta0s, plotDataw1.LowQs, plotDataw1.UpQs, 
                 alpha=0.2, facecolor="#F25757")
plt.plot(plotDataw2.theta0s, plotDataw2.means, "o-.", color="#1094E9")
plt.fill_between(plotDataw2.theta0s, plotDataw2.LowQs, plotDataw2.UpQs, 
                 alpha=0.2, facecolor="#1094E9")

# %% [markdown]
# ## 1.3 UIPJS-M

# %%
rawUIPJSM = load_pkl(root/f"Boxplot_M_UIPJS100{fname}.pkl")

# %%
UIPJSM = ddict(list)
for dat in rawUIPJSM:
    for key, item in dat.items():
        UIPJSM[key].append(np.mean(item))

# %%
plotData = getPlotData(UIPJSM)
plt.plot(plotData.theta0s, plotData.means, "o-", color="#F25757")
plt.fill_between(plotData.theta0s, plotData.LowQs, plotData.UpQs, 
                 alpha=0.2, facecolor="#F25757")

# %% [markdown]
# ### UIPJS-M-Long

# %%
rawUIPJSM_ext = load_pkl(root/f"Boxplot_M_UIPJS100{fname}_dev.pkl")
UIPJSM_ext = ddict(list)
for dat in rawUIPJSM_ext:
    for key, item in dat.items():
        UIPJSM_ext[key].append(np.mean(item))

# %%
plotData_ext = getPlotData(UIPJSM_ext)
allMeans = np.concatenate([plotData.means, plotData_ext.means])
allTheta0s = np.concatenate([plotData.theta0s, plotData_ext.theta0s])

plt.figure(figsize=[5, 5])
plt.plot(allTheta0s, allMeans, "o-", color="#F25757")
plt.xlabel(r"$\theta_0$")
plt.ylabel(r"Posterior mean of $M$")
# plt.savefig("../plots/dynaNormUIPJS_Long.pdf")
# Out:
# Text(0, 0.5, 'Posterior mean of $M$')

# %% [markdown]
# ## 1.2 UIPJS-w

# %%
rawUIPJSw = load_pkl(root/f"Boxplot_w_UIPJS100{fname}.pkl")

# %%
UIPJSm1 = ddict(list)
UIPJSm2 = ddict(list)
UIPJSw1 = ddict(list)
UIPJSw2 = ddict(list)
for dat in rawUIPJSw:
    for key in dat[0].keys():
        ws = dat[0][key]
        Ms = dat[1][key]
        ms = ws * Ms.reshape(-1, 1)
        m = ms.mean(axis=0)
        UIPJSw1[key].append(ws[0])
        UIPJSw2[key].append(ws[1])
        UIPJSm1[key].append(m[0])
        UIPJSm2[key].append(m[1])

# %%
plotDatam1 = getPlotData(UIPJSm1)
plotDatam2 = getPlotData(UIPJSm2)
plotDataw1 = getPlotData(UIPJSw1)
plotDataw2 = getPlotData(UIPJSw2)

plt.figure(figsize=[10, 5])
plt.subplot(121)
plt.plot(plotDatam1.theta0s, plotDatam1.means, "*-", color="#F25757")
plt.fill_between(plotDatam1.theta0s, plotDatam1.LowQs, plotDatam1.UpQs, 
                 alpha=0.2, facecolor="#F25757")
plt.plot(plotDatam2.theta0s, plotDatam2.means, "o-.", color="#1094E9")
plt.fill_between(plotDatam2.theta0s, plotDatam2.LowQs, plotDatam2.UpQs, 
                 alpha=0.2, facecolor="#1094E9")

plt.subplot(122)
plt.plot(plotDataw1.theta0s, plotDataw1.means, "-*", color="#F25757")
plt.fill_between(plotDataw1.theta0s, plotDataw1.LowQs, plotDataw1.UpQs, 
                 alpha=0.2, facecolor="#F25757")
plt.plot(plotDataw2.theta0s, plotDataw2.means, "o-.", color="#1094E9")
plt.fill_between(plotDataw2.theta0s, plotDataw2.LowQs, plotDataw2.UpQs, 
                 alpha=0.2, facecolor="#1094E9")

# %% [markdown]
# # 2. Plot the results

# %%
plotData = getPlotData(UIPDM)
plotDatam1 = getPlotData(UIPDm1)
plotDatam2 = getPlotData(UIPDm2)
plotDataw1 = getPlotData(UIPDw1)
plotDataw2 = getPlotData(UIPDw2)

plotData_ext = getPlotData(UIPDM_ext)
allMeans = np.concatenate([plotData.means, plotData_ext.means])
allTheta0s = np.concatenate([plotData.theta0s, plotData_ext.theta0s])

fig = plt.figure(figsize=[15, 5])

plt.subplot(1, 3, 1)
if n == 40:
    plt.ylim([0, 25])
else:
    plt.ylim([0, 45])
plt.xlabel(r"$\theta_0$")
plt.ylabel(r"Posterior mean of $M$")
plt.plot(allTheta0s, allMeans, "o-", color="#F25757")
#plt.fill_between(plotData.theta0s, plotData.LowQs, plotData.UpQs, 
#                 alpha=0.2, facecolor="#F25757")
plt.annotate('$D_1$ $(\\theta_1=-0.3)$\n$D_2$ $(\\theta_2=0.3)$', xy=(0.95, 0.95), xycoords='axes fraction',
            size=10, ha='right', va='top', ma="left",
            bbox=dict(boxstyle='round', fc='w', alpha=0.5))

plt.subplot(1, 3, 2)
plt.ylim([0, 1.1])
plt.xlabel(r"$\theta_0$")
plt.ylabel(r"Posterior mean of $w_1(w_2)$")
plt.plot(plotDataw1.theta0s, plotDataw1.means, "-*", color="#F25757", label=r"$D_1$ $(\theta_1=$" + "-0.3)")
#plt.fill_between(plotDataw1.theta0s, plotDataw1.LowQs, plotDataw1.UpQs, 
#                 alpha=0.2, facecolor="#F25757")
plt.plot(plotDataw2.theta0s, plotDataw2.means, "o-.", color="#1094E9", label=r"$D_2$ $(\theta_2=$" + "0.3)")
#plt.fill_between(plotDataw2.theta0s, plotDataw2.LowQs, plotDataw2.UpQs, 
#                 alpha=0.2, facecolor="#1094E9")
plt.legend()

plt.subplot(1, 3, 3)
if n == 40:
    plt.ylim([0, 25])
else:
    plt.ylim([0, 45])
plt.xlabel(r"$\theta_0$")
plt.ylabel(r"Posterior mean of $Mw_1(Mw_2)$")
plt.plot(plotDatam1.theta0s, plotDatam1.means, "*-", color="#F25757", label=r"$D_1$ $(\theta_1=$" + "-0.3)")
#plt.fill_between(plotDatam1.theta0s, plotDatam1.LowQs, plotDatam1.UpQs, 
#                 alpha=0.2, facecolor="#F25757")
plt.plot(plotDatam2.theta0s, plotDatam2.means, "o-.", color="#1094E9", label=r"$D_2$ $(\theta_2=$" + "0.3)")
#plt.fill_between(plotDatam2.theta0s, plotDatam2.LowQs, plotDatam2.UpQs, 
#                 alpha=0.2, facecolor="#1094E9")
_ = plt.legend()

plt.savefig(f"../plots/dynaNormUIPD{fname}.pdf")

# %%
plotData = getPlotData(UIPJSM)
plotDatam1 = getPlotData(UIPJSm1)
plotDatam2 = getPlotData(UIPJSm2)
plotDataw1 = getPlotData(UIPJSw1)
plotDataw2 = getPlotData(UIPJSw2)
plotData_ext = getPlotData(UIPJSM_ext)
allMeans = np.concatenate([plotData.means, plotData_ext.means])
allTheta0s = np.concatenate([plotData.theta0s, plotData_ext.theta0s])


fig = plt.figure(figsize=[15, 5])

plt.subplot(1, 3, 1)
if n == 40:
    plt.ylim([0, 25])
else:
    plt.ylim([0, 45])
plt.xlabel(r"$\theta_0$")
plt.ylabel(r"Posterior mean of $M$")
plt.plot(allTheta0s, allMeans, "o-", color="#F25757")
#plt.fill_between(plotData.theta0s, plotData.LowQs, plotData.UpQs, 
#                 alpha=0.2, facecolor="#F25757")
plt.annotate('$D_1$ $(\\theta_1=-0.3)$\n$D_2$ $(\\theta_2=0.3)$', xy=(0.95, 0.95), xycoords='axes fraction',
            size=10, ha='right', va='top', ma="left",
            bbox=dict(boxstyle='round', fc='w', alpha=0.5))

plt.subplot(1, 3, 2)
plt.ylim([0, 1.1])
plt.xlabel(r"$\theta_0$")
plt.ylabel(r"$w_1(w_2)$")
plt.plot(plotDataw1.theta0s, plotDataw1.means, "-*", color="#F25757", label=r"$D_1$ $(\theta_1=$" + "-0.3)")
#plt.fill_between(plotDataw1.theta0s, plotDataw1.LowQs, plotDataw1.UpQs, 
#                 alpha=0.2, facecolor="#F25757")
plt.plot(plotDataw2.theta0s, plotDataw2.means, "o-.", color="#1094E9", label=r"$D_2$ $(\theta_2=$" + "0.3)")
#plt.fill_between(plotDataw2.theta0s, plotDataw2.LowQs, plotDataw2.UpQs, 
#                 alpha=0.2, facecolor="#1094E9")
plt.legend()

plt.subplot(1, 3, 3)
if n == 40:
    plt.ylim([0, 25])
else: 
    plt.ylim([0, 45])
plt.xlabel(r"$\theta_0$")
plt.ylabel(r"Posterior mean of $Mw_1(Mw_2)$")
plt.plot(plotDatam1.theta0s, plotDatam1.means, "*-", color="#F25757", label=r"$D_1$ $(\theta_1=$" + "-0.3)")
#plt.fill_between(plotDatam1.theta0s, plotDatam1.LowQs, plotDatam1.UpQs, 
#                 alpha=0.2, facecolor="#F25757")
plt.plot(plotDatam2.theta0s, plotDatam2.means, "o-.", color="#1094E9", label=r"$D_2$ $(\theta_2=$" + "0.3)")
#plt.fill_between(plotDatam2.theta0s, plotDatam2.LowQs, plotDatam2.UpQs, 
#                 alpha=0.2, facecolor="#1094E9")
_ = plt.legend()


plt.savefig(f"../plots/dynaNormUIPJS{fname}.pdf")
